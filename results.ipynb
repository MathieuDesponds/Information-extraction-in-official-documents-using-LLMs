# %%
import warnings
warnings.filterwarnings('ignore')

from ner.plot_results import *

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# <a id="0"></a> <br>
# # NER with LLM Results
#
# ## Table of Contents
#
# 1. [Ontonote 5 Dataset](#1)
# 1. [Results without finetuning](#2)
#     1. [The impact of few shots](#21)
#     1. [The impact of more explenations](#22)
# 1. [Results with finetuning](#3)
#     1. [The impact of few shots](#31)
#     1. [The impact of more explenations](#32)
# 1. [The impact of finetuning](#4)
#     1. [The impact of few shots](#41)
#     1. [The impact of more explenations](#42)
# 1. [The impact of few shots](#5)

# %% [markdown]
# <a id="1"></a>
# ## Ontonote 5 dataset
# The dataset used is a subset of the Ontonote 5 dataset that contains 18 tags that are `['CARDINAL', 'ORDINAL', 'WORK_OF_ART', 'PERSON', 'LOC', 'DATE', 'PERCENT', 'PRODUCT', 'MONEY', 'FAC', 'TIME', 'ORG', 'QUANTITY', 'LANGUAGE', 'GPE', 'LAW', 'NORP', 'EVENT']`
#
# Sentence with less than 30 tokens were removed

# %% [markdown]
# <a id="2"></a>
# ## Results without finetuning

# %%
df = show_results(with_ft = False)

# %% [markdown]
# <a id="21"></a>
# ### The impact of few shots

# %%
summary, table = show_diff_few_shots(with_ft = False)
print(summary)
# Out:
# For Ontonote5 :
#     The mean difference between results that uses few_shots and those that do not and raw is
#      0.184 with confidence 95% student interval (0.155, 0.212)
# For Conll2003_cleaned :
#     The mean difference between results that uses few_shots and those that do not and raw is
#      0.278 with confidence 95% student interval (0.188, 0.368)

# %% [markdown]
# <a id="22"></a>
# ### The impact of explenations

# %%
summary, table = show_diff_plus_plus(with_ft = False)
print(summary)
# Out:
# For Ontonote5 :
#     The mean difference between results that had a detailled explenation and thos that did not is
#      0.004 with confidence 95% student interval (0.003, 0.005)

# %% [markdown]
# <a id="3"></a>
# ## Results with finetuning

# %%
show_results(with_ft = True)
# Out:
#                                                 model  f1_mean  \
# 54                   mistral-7b-v0.1-ft-raw-2000-Q5_0    0.586
# 50                   mistral-7b-v0.1-ft-raw-2000-Q5_0    0.577
# 55                   mistral-7b-v0.1-ft-raw-2000-Q5_0    0.563
# 56                   mistral-7b-v0.1-ft-raw-2000-Q5_0    0.552
# 47  mistral-7b-v0.1-ft-raw-2000-Q5_0-ft-raw-2000-Q5_0    0.227
# 46  mistral-7b-v0.1-ft-raw-2000-Q5_0-ft-raw-2000-Q5_0    0.212
# 45  mistral-7b-v0.1-ft-raw-2000-Q5_0-ft-raw-2000-Q...    0.142
# 44  mistral-7b-v0.1-ft-raw-2000-Q5_0-ft-raw-2000-Q...    0.131
# 67                   mistral-7b-v0.1-ft-raw-2000-Q5_0    0.076
# 68                   mistral-7b-v0.1-ft-raw-2000-Q5_0    0.072
# 63                   mistral-7b-v0.1-ft-raw-2000-Q5_0    0.011
# 66                   mistral-7b-v0.1-ft-raw-2000-Q5_0    0.010
#
#      f1_conf_inter prompt_technique few_shot_tecnique  nb_few_shots precision  \
# 54  (0.536, 0.635)       discussion          no-shots             0       300
# 50  (0.521, 0.633)       discussion          no-shots             0       300
# 55   (0.556, 0.57)       discussion          sentence             3       300
# 56  (0.538, 0.565)       discussion          sentence             3       300
# 47  (0.207, 0.246)           filing          sentence             3       300
# 46  (0.199, 0.225)           filing          sentence             3       300
# 45   (0.134, 0.15)           filing          no-shots             0       300
# 44  (0.116, 0.146)           filing          no-shots             0       300
# 67  (0.068, 0.084)          wrapper          sentence             3       300
# 68  (0.063, 0.081)          wrapper          sentence             3       300
# 63  (0.005, 0.017)          wrapper          no-shots             0       300
# 66  (0.005, 0.016)          wrapper          no-shots             0       300
#
#     plus_plus                tech_name
# 54      False        With 0 few_shots
# 50       True  With 0 few_shots and ++
# 55      False        With 3 few_shots
# 56       True  With 3 few_shots and ++
# 47       True  With 3 few_shots and ++
# 46      False        With 3 few_shots
# 45      False        With 0 few_shots
# 44       True  With 0 few_shots and ++
# 67      False        With 3 few_shots
# 68       True  With 3 few_shots and ++
# 63       True  With 0 few_shots and ++
# 66      False        With 0 few_shots
#                                          model  f1_mean   f1_conf_inter  \
# 85  mistral-7b-v0.1-ft-raw-2000-Q5_0-conll2003    0.668  (0.601, 0.734)
# 90  mistral-7b-v0.1-ft-raw-conll2003-2000-Q5_0    0.658  (0.605, 0.711)
# 88  mistral-7b-v0.1-ft-raw-2000-Q5_0-conll2003    0.627  (0.566, 0.688)
# 87  mistral-7b-v0.1-ft-raw-2000-Q5_0-conll2003    0.619  (0.523, 0.714)
#
#    prompt_technique few_shot_tecnique  nb_few_shots precision  plus_plus  \
# 85       discussion          no-shots             0       300       True
# 90          wrapper          sentence             3       300       True
# 88          wrapper          no-shots             0       300       True
# 87       discussion          sentence             3       300       True
#
#                   tech_name
# 85  With 0 few_shots and ++
# 90  With 3 few_shots and ++
# 88  With 0 few_shots and ++
# 87  With 3 few_shots and ++

# %% [markdown]
# <a id="31"></a>
# ### The impact of few shots

# %%
summary, table = show_diff_few_shots(with_ft = True)
print(summary)
# Out:
# For Ontonote5 :
#     The mean difference between results that uses few_shots and those that do not and raw is
#      0.149 with confidence 95% student interval (0.107, 0.190)
# For Conll2003_cleaned :
#     The mean difference between results that uses few_shots and those that do not and raw is
#      nan with confidence 95% student interval (nan, nan)

# %% [markdown]
# <a id="32"></a>
# ### The impact of explenations

# %%
summary, table = show_diff_plus_plus(with_ft = True)
print(summary)
# Out:
# For Ontonote5 :
#     The mean difference between results that had a detailled explenation and thos that did not is
#      -0.001 with confidence 95% student interval (-0.004, 0.001)

# %% [markdown]
# <a id="4"></a>
# ## The impact of finetuning

# %% [markdown]
# <a id="41"></a>
# ### Without any few shots

# %%
summary, table = show_diff_ft(with_few_shots = False)
print(summary)
table
# Out:
# For Conll2003_cleaned :
#     The mean difference between results that used a finetuned model and those that do not is
#      0.544 with confidence 95% student interval (0.368, 0.719)
# {'conll2003_cleaned': with_ft prompt_technique  plus_plus  nb_few_shots  result   True  False
#  0             discussion       True             0   0.524  0.668  0.144
#  1                wrapper       True             0   0.563  0.627  0.064}

# %% [markdown]
# <a id="42"></a>
# ### With few shots

# %%
summary, table = show_diff_ft(with_few_shots = True)
print(summary)
table

# %% [markdown]
# <a id="5"></a>
# ## Impact of few shots

# %%
df = show_results_few_shots(datasets = ["ontonote5", "conll2003_cleaned"])
# df.sort_values(['model', 'prompt_technique', 'nb_few_shots'])

# %%
summary, table = show_diff_ft_few_shots(datasets = ["ontonote5"])
print(summary)
# Out:
# For Ontonote5 :
#     The mean score increase with few_shots between finetuning and without finetuning is
#      0.024 with confidence 95% student interval (-0.029, 0.077)
