# %%
import warnings
warnings.filterwarnings('ignore')

from ner.plot_results import *

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# <a id="0"></a> <br>
# # NER with LLM Results
#
# ## Table of Contents
#
# 1. [Ontonote 5 Dataset](#1)
# 1. [Results without finetuning](#2)
#     1. [The impact of few shots](#21)
#     1. [The impact of more explenations](#22)
# 1. [Results with finetuning](#3)
#     1. [The impact of few shots](#31)
#     1. [The impact of more explenations](#32)
# 1. [The impact of finetuning](#4)
#     1. [The impact of few shots](#41)
#     1. [The impact of more explenations](#42)
# 1. [The impact of few shots](#5)

# %% [markdown]
# <a id="1"></a>
# ## Ontonote 5 dataset
# The dataset used is a subset of the Ontonote 5 dataset that contains 18 tags that are `['CARDINAL', 'ORDINAL', 'WORK_OF_ART', 'PERSON', 'LOC', 'DATE', 'PERCENT', 'PRODUCT', 'MONEY', 'FAC', 'TIME', 'ORG', 'QUANTITY', 'LANGUAGE', 'GPE', 'LAW', 'NORP', 'EVENT']`
#
# Sentence with less than 30 tokens were removed

# %% [markdown]
# <a id="2"></a>
# ## Results without finetuning

# %%
df = show_results(with_ft = False)
# Out:
#               model  f1_mean   f1_conf_inter  \
# 43  mistral-7b-v0.1    0.323   (0.297, 0.35)
# 42  mistral-7b-v0.1    0.321  (0.275, 0.367)
# 34  mistral-7b-v0.1    0.246  (0.216, 0.275)
# 28  mistral-7b-v0.1    0.238  (0.202, 0.274)
# 33  mistral-7b-v0.1    0.238  (0.205, 0.271)
# 27  mistral-7b-v0.1    0.236  (0.194, 0.277)
# 16  mistral-7b-v0.1    0.161  (0.132, 0.191)
# 15  mistral-7b-v0.1    0.152  (0.098, 0.205)
# 19  mistral-7b-v0.1    0.119  (0.103, 0.135)
# 26  mistral-7b-v0.1    0.110    (0.1, 0.119)
# 12  mistral-7b-v0.1    0.088  (0.077, 0.098)
# 14  mistral-7b-v0.1    0.081  (0.077, 0.084)
# 41  mistral-7b-v0.1    0.026  (0.009, 0.043)
# 37  mistral-7b-v0.1    0.021  (0.011, 0.031)
#
#                     prompt_technique few_shot_tecnique  nb_few_shots  \
# 43                           wrapper          sentence             3
# 42                           wrapper          sentence             3
# 34  multi_prompt-get-entities-tagger          sentence             3
# 28                        discussion          sentence             3
# 33  multi_prompt-get-entities-tagger          sentence             3
# 27                        discussion          sentence             3
# 16                            filing          sentence             3
# 15                            filing          sentence             3
# 19                        discussion          no-shots             0
# 26                        discussion          no-shots             0
# 12                            filing          no-shots             0
# 14                            filing          no-shots             0
# 41                           wrapper          no-shots             0
# 37                           wrapper          no-shots             0
#
#    precision  plus_plus                tech_name
# 43       300       True  With 3 few_shots and ++
# 42       300      False        With 3 few_shots
# 34       300       True  With 3 few_shots and ++
# 28       300       True  With 3 few_shots and ++
# 33       300      False        With 3 few_shots
# 27       300      False        With 3 few_shots
# 16       300       True  With 3 few_shots and ++
# 15       300      False        With 3 few_shots
# 19       300       True  With 0 few_shots and ++
# 26       300      False        With 0 few_shots
# 12       300       True  With 0 few_shots and ++
# 14       300      False        With 0 few_shots
# 41       300      False        With 0 few_shots
# 37       300       True  With 0 few_shots and ++
#               model  f1_mean   f1_conf_inter prompt_technique  \
# 60  mistral-7b-v0.1    0.432  (0.356, 0.508)       discussion
# 80  mistral-7b-v0.1    0.332  (0.297, 0.367)          wrapper
# 52  mistral-7b-v0.1    0.144  (0.127, 0.162)       discussion
# 74  mistral-7b-v0.1    0.064  (0.013, 0.116)          wrapper
#
#    few_shot_tecnique  nb_few_shots precision  plus_plus  \
# 60          sentence             3       300       True
# 80          sentence             3       300       True
# 52          no-shots             0       300       True
# 74          no-shots             0       300       True
#
#                   tech_name
# 60  With 3 few_shots and ++
# 80  With 3 few_shots and ++
# 52  With 0 few_shots and ++
# 74  With 0 few_shots and ++

# %% [markdown]
# <a id="21"></a>
# ### The impact of few shots

# %%
summary, table = show_diff_few_shots(with_ft = False)
print(summary)
# Out:
# For Ontonote5 :
#     The mean difference between results that uses few_shots and those that do not and raw is
#      0.184 with confidence 95% student interval (0.155, 0.212)
# For Conll2003_cleaned :
#     The mean difference between results that uses few_shots and those that do not and raw is
#      0.278 with confidence 95% student interval (0.188, 0.368)

# %% [markdown]
# <a id="22"></a>
# ### The impact of explenations

# %%
summary, table = show_diff_plus_plus(with_ft = False)
print(summary)
# Out:
# For Ontonote5 :
#     The mean difference between results that had a detailled explenation and thos that did not is
#      0.004 with confidence 95% student interval (0.003, 0.005)

# %% [markdown]
# <a id="3"></a>
# ## Results with finetuning

# %%
show_results(with_ft = True)

# %% [markdown]
# <a id="31"></a>
# ### The impact of few shots

# %%
summary, table = show_diff_few_shots(with_ft = True)
print(summary)
# Out:
# For Ontonote5 :
#     The mean difference between results that uses few_shots and those that do not and raw is
#      0.149 with confidence 95% student interval (0.107, 0.190)
# For Conll2003_cleaned :
#     The mean difference between results that uses few_shots and those that do not and raw is
#      nan with confidence 95% student interval (nan, nan)

# %% [markdown]
# <a id="32"></a>
# ### The impact of explenations

# %%
summary, table = show_diff_plus_plus(with_ft = True)
print(summary)
# Out:
# For Ontonote5 :
#     The mean difference between results that had a detailled explenation and thos that did not is
#      -0.001 with confidence 95% student interval (-0.004, 0.001)

# %% [markdown]
# <a id="4"></a>
# ## The impact of finetuning

# %% [markdown]
# <a id="41"></a>
# ### Without any few shots

# %%
summary, table = show_diff_ft(with_few_shots = False)
print(summary)
table
# Out:
# For Conll2003_cleaned :
#     The mean difference between results that used a finetuned model and those that do not is
#      0.544 with confidence 95% student interval (0.368, 0.719)
# {'conll2003_cleaned': with_ft prompt_technique  plus_plus  nb_few_shots  result   True  False
#  0             discussion       True             0   0.524  0.668  0.144
#  1                wrapper       True             0   0.563  0.627  0.064}

# %% [markdown]
# <a id="42"></a>
# ### With few shots

# %%
summary, table = show_diff_ft(with_few_shots = True)
print(summary)
table

# %% [markdown]
# <a id="5"></a>
# ## Impact of few shots

# %%
df = show_results_few_shots(datasets = ["ontonote5", "conll2003_cleaned"])
# df.sort_values(['model', 'prompt_technique', 'nb_few_shots'])
# Out:
#                                model  f1_mean   f1_conf_inter  \
# 49  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.577  (0.538, 0.617)
# 50  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.577  (0.521, 0.633)
# 51  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.572  (0.557, 0.586)
# 56  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.552  (0.538, 0.565)
# 38                   mistral-7b-v0.1    0.433  (0.371, 0.494)
# 36                   mistral-7b-v0.1    0.414  (0.369, 0.459)
# 43                   mistral-7b-v0.1    0.323  (0.297, 0.350)
# 18                   mistral-7b-v0.1    0.258  (0.207, 0.309)
# 28                   mistral-7b-v0.1    0.238  (0.202, 0.274)
# 20                   mistral-7b-v0.1    0.236  (0.217, 0.256)
# 19                   mistral-7b-v0.1    0.119  (0.103, 0.135)
# 68  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.072  (0.063, 0.081)
# 62  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.063  (0.054, 0.073)
# 64  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.042  (0.036, 0.049)
# 37                   mistral-7b-v0.1    0.021  (0.011, 0.031)
# 63  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.011  (0.005, 0.017)
#
#    prompt_technique few_shot_tecnique  nb_few_shots precision  plus_plus  \
# 49       discussion          sentence             5       300       True
# 50       discussion          no-shots             0       300       True
# 51       discussion          sentence            10       300       True
# 56       discussion          sentence             3       300       True
# 38          wrapper          sentence            10       300       True
# 36          wrapper          sentence             5       300       True
# 43          wrapper          sentence             3       300       True
# 18       discussion          sentence             5       300       True
# 28       discussion          sentence             3       300       True
# 20       discussion          sentence            10       300       True
# 19       discussion          no-shots             0       300       True
# 68          wrapper          sentence             3       300       True
# 62          wrapper          sentence             5       300       True
# 64          wrapper          sentence            10       300       True
# 37          wrapper          no-shots             0       300       True
# 63          wrapper          no-shots             0       300       True
#
#        ft                          x_names          tech_name
# 49   True     discussion | With finetuning  With  5 few shots
# 50   True     discussion | With finetuning  With  0 few shots
# 51   True     discussion | With finetuning  With 10 few shots
# 56   True     discussion | With finetuning  With  3 few shots
# 38  False     wrapper | Without finetuning  With 10 few shots
# 36  False     wrapper | Without finetuning  With  5 few shots
# 43  False     wrapper | Without finetuning  With  3 few shots
# 18  False  discussion | Without finetuning  With  5 few shots
# 28  False  discussion | Without finetuning  With  3 few shots
# 20  False  discussion | Without finetuning  With 10 few shots
# 19  False  discussion | Without finetuning  With  0 few shots
# 68   True        wrapper | With finetuning  With  3 few shots
# 62   True        wrapper | With finetuning  With  5 few shots
# 64   True        wrapper | With finetuning  With 10 few shots
# 37  False     wrapper | Without finetuning  With  0 few shots
# 63   True        wrapper | With finetuning  With  0 few shots
#                                          model  f1_mean   f1_conf_inter  \
# 84            mistral-7b-v0.1-ft-raw-2000-Q5_0    0.780  (0.722, 0.838)
# 85  mistral-7b-v0.1-ft-raw-conll2003-2000-Q5_0    0.676  (0.547, 0.806)
# 88  mistral-7b-v0.1-ft-raw-conll2003-2000-Q5_0    0.672  (0.624, 0.720)
# 89  mistral-7b-v0.1-ft-raw-conll2003-2000-Q5_0    0.658  (0.605, 0.711)
# 86            mistral-7b-v0.1-ft-raw-2000-Q5_0    0.644  (0.539, 0.749)
# 83            mistral-7b-v0.1-ft-raw-2000-Q5_0    0.634  (0.502, 0.766)
# 87  mistral-7b-v0.1-ft-raw-2000-Q5_0-conll2003    0.627  (0.566, 0.688)
# 55                             mistral-7b-v0.1    0.461  (0.350, 0.572)
# 60                             mistral-7b-v0.1    0.432  (0.356, 0.508)
# 76                             mistral-7b-v0.1    0.357  (0.324, 0.390)
# 80                             mistral-7b-v0.1    0.332  (0.297, 0.367)
# 52                             mistral-7b-v0.1    0.144  (0.127, 0.162)
# 74                             mistral-7b-v0.1    0.064  (0.013, 0.116)
#
#    prompt_technique few_shot_tecnique  nb_few_shots precision  plus_plus  \
# 84       discussion          no-shots             0       300       True
# 85       discussion          sentence            10       300       True
# 88          wrapper          sentence            10       300       True
# 89          wrapper          sentence             3       300       True
# 86       discussion          sentence             3       300       True
# 83       discussion          sentence             5       300       True
# 87          wrapper          no-shots             0       300       True
# 55       discussion          sentence            10       300       True
# 60       discussion          sentence             3       300       True
# 76          wrapper          sentence            10       300       True
# 80          wrapper          sentence             3       300       True
# 52       discussion          no-shots             0       300       True
# 74          wrapper          no-shots             0       300       True
#
#        ft                          x_names          tech_name
# 84   True     discussion | With finetuning  With  0 few shots
# 85   True     discussion | With finetuning  With 10 few shots
# 88   True        wrapper | With finetuning  With 10 few shots
# 89   True        wrapper | With finetuning  With  3 few shots
# 86   True     discussion | With finetuning  With  3 few shots
# 83   True     discussion | With finetuning  With  5 few shots
# 87   True        wrapper | With finetuning  With  0 few shots
# 55  False  discussion | Without finetuning  With 10 few shots
# 60  False  discussion | Without finetuning  With  3 few shots
# 76  False     wrapper | Without finetuning  With 10 few shots
# 80  False     wrapper | Without finetuning  With  3 few shots
# 52  False  discussion | Without finetuning  With  0 few shots
# 74  False     wrapper | Without finetuning  With  0 few shots

# %%
summary, table = show_diff_ft_few_shots(datasets = ["ontonote5", 'conll2003_cleaned'])
print(summary)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /myhome/Master-thesis/results.ipynb Cell 23 line 1
# ----> <a href='vscode-notebook-cell://ssh-remote%2B127.0.0.1/myhome/Master-thesis/results.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> summary, table = show_diff_ft_few_shots(datasets = ["ontonote5", 'conll2003_cleaned'])
#       <a href='vscode-notebook-cell://ssh-remote%2B127.0.0.1/myhome/Master-thesis/results.ipynb#X31sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> print(summary)
#
# File /myhome/Master-thesis/ner/plot_results.py:216, in show_diff_ft_few_shots(datasets)
#     213     df_to_show = df_to_show[df_results['nb_test_run'] * df_results['len_data_test'] == '300']
#     215 # Pivot the DataFrame to have 'True' and 'False' types as columns
# --> 216 pivot_df = df_to_show.pivot(index=['prompt_technique',  'nb_few_shots'], columns='ft', values='f1_mean').reset_index()
#     218 # Subtract 'False' from 'True'
#     219 pivot_df['result'] = pivot_df[True] - pivot_df[False]
#
# File /myhome/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:9025, in DataFrame.pivot(self, columns, index, values)
#    9018 @Substitution("")
#    9019 @Appender(_shared_docs["pivot"])
#    9020 def pivot(
#    9021     self, *, columns, index=lib.no_default, values=lib.no_default
#    9022 ) -> DataFrame:
#    9023     from pandas.core.reshape.pivot import pivot
# -> 9025     return pivot(self, index=index, columns=columns, values=values)
#
# File /myhome/miniconda3/lib/python3.10/site-packages/pandas/core/reshape/pivot.py:553, in pivot(data, columns, index, values)
#     549         indexed = data._constructor_sliced(data[values]._values, index=multiindex)
#     550 # error: Argument 1 to "unstack" of "DataFrame" has incompatible type "Union
#     551 # [List[Any], ExtensionArray, ndarray[Any, Any], Index, Series]"; expected
#     552 # "Hashable"
# --> 553 result = indexed.unstack(columns_listlike)  # type: ignore[arg-type]
#     554 result.index.names = [
#     555     name if name is not lib.no_default else None for name in result.index.names
#     556 ]
#     558 return result
#
# File /myhome/miniconda3/lib/python3.10/site-packages/pandas/core/series.py:4459, in Series.unstack(self, level, fill_value, sort)
#    4414 """
#    4415 Unstack, also known as pivot, Series with MultiIndex to produce DataFrame.
#    4416
#    (...)
#    4455 b    2    4
#    4456 """
#    4457 from pandas.core.reshape.reshape import unstack
# -> 4459 return unstack(self, level, fill_value, sort)
#
# File /myhome/miniconda3/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:517, in unstack(obj, level, fill_value, sort)
#     515 if is_1d_only_ea_dtype(obj.dtype):
#     516     return _unstack_extension_series(obj, level, fill_value, sort=sort)
# --> 517 unstacker = _Unstacker(
#     518     obj.index, level=level, constructor=obj._constructor_expanddim, sort=sort
#     519 )
#     520 return unstacker.get_result(
#     521     obj._values, value_columns=None, fill_value=fill_value
#     522 )
#
# File /myhome/miniconda3/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:154, in _Unstacker.__init__(self, index, level, constructor, sort)
#     146 if num_cells > np.iinfo(np.int32).max:
#     147     warnings.warn(
#     148         f"The following operation may generate {num_cells} cells "
#     149         f"in the resulting pandas object.",
#     150         PerformanceWarning,
#     151         stacklevel=find_stack_level(),
#     152     )
# --> 154 self._make_selectors()
#
# File /myhome/miniconda3/lib/python3.10/site-packages/pandas/core/reshape/reshape.py:210, in _Unstacker._make_selectors(self)
#     207 mask.put(selector, True)
#     209 if mask.sum() < len(self.index):
# --> 210     raise ValueError("Index contains duplicate entries, cannot reshape")
#     212 self.group_index = comp_index
#     213 self.mask = mask
#
# ValueError: Index contains duplicate entries, cannot reshape
