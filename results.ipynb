# %%
import warnings
warnings.filterwarnings('ignore')

from ner.plot_results import *

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# <a id="0"></a> <br>
# # NER with LLM Results
#
# ## Table of Contents
#
# 1. [Ontonote 5 Dataset](#1)
# 1. [Results without finetuning](#2)
#     1. [The impact of few shots](#21)
#     1. [The impact of more explenations](#22)
# 1. [Results with finetuning](#3)
#     1. [The impact of few shots](#31)
#     1. [The impact of more explenations](#32)
# 1. [The impact of finetuning](#4)
#     1. [The impact of few shots](#41)
#     1. [The impact of more explenations](#42)
# 1. [The impact of few shots](#5)

# %% [markdown]
# <a id="1"></a>
# ## Ontonote 5 dataset
# The dataset used is a subset of the Ontonote 5 dataset that contains 18 tags that are `['CARDINAL', 'ORDINAL', 'WORK_OF_ART', 'PERSON', 'LOC', 'DATE', 'PERCENT', 'PRODUCT', 'MONEY', 'FAC', 'TIME', 'ORG', 'QUANTITY', 'LANGUAGE', 'GPE', 'LAW', 'NORP', 'EVENT']`
#
# Sentence with less than 30 tokens were removed

# %% [markdown]
# <a id="2"></a>
# ## Results without finetuning

# %%
show_results_ontonote(with_ft = False)

# %% [markdown]
# <a id="21"></a>
# ### The impact of few shots

# %%
summary, table = show_diff_few_shots(with_ft = False)
print(summary)
# Out:
# The mean difference between results that uses few_shots and those that do not and raw is
#      0.184 with confidence 95% student interval (0.155, 0.212)

# %% [markdown]
# <a id="22"></a>
# ### The impact of explenations

# %%
summary, table = show_diff_plus_plus(with_ft = False)
print(summary)
# Out:
# The mean difference between plus plus and raw is
#      0.004 with confidence 95% student interval (0.003, 0.005)

# %% [markdown]
# <a id="3"></a>
# ## Results with finetuning

# %%
show_results_ontonote(with_ft = True)

# %% [markdown]
# <a id="31"></a>
# ### The impact of few shots

# %%
summary, table = show_diff_few_shots(with_ft = True)
print(summary)

# %% [markdown]
# <a id="32"></a>
# ### The impact of explenations

# %%
summary, table = show_diff_plus_plus(with_ft = True)
print(summary)

# %% [markdown]
# <a id="4"></a>
# ## The impact of finetuning

# %% [markdown]
# <a id="41"></a>
# ### Without any few shots

# %%
summary, table = show_diff_ft(with_few_shots = False)
print(summary)
table
# Out:
# The mean difference between results that have more detaillled explenations fo the task and those that do not is
#      0.021 with confidence 95% student interval (0.015, 0.028)
# with_ft                  prompt_technique  plus_plus precision  result   True  \
# 0                              discussion      False       300   0.012  0.122
# 1                              discussion       True       300   0.003  0.122
# 2                                  filing      False       300   0.061  0.142
# 3                                  filing       True       300   0.043  0.131
# 4        multi_prompt-get-entities-tagger      False       300   0.000  0.000
# 5        multi_prompt-get-entities-tagger       True       300   0.000  0.000
# 6                                 wrapper      False       300   0.025  0.051
# 7                                 wrapper       True       300   0.027  0.048
#
# with_ft  False
# 0        0.110
# 1        0.119
# 2        0.081
# 3        0.088
# 4        0.000
# 5        0.000
# 6        0.026
# 7        0.021

# %% [markdown]
# <a id="42"></a>
# ### With few shots

# %%
show_diff_ft(with_few_shots = True)

# %% [markdown]
# <a id="5"></a>
# ## Impact of few shots

# %%
show_results_few_shots()

# %%
summary, table = show_diff_ft_few_shots()
print(summary)
table
# Out:
# The mean score increase with few_shots between finetuning and without finetuning is
#      0.016 with confidence 95% student interval (0.006, 0.027)
# ft prompt_technique  nb_few_shots  result   True  False
# 0        discussion             0   0.012  0.122  0.110
# 1        discussion             3   0.045  0.281  0.236
# 2        discussion             5   0.000  0.284  0.284
# 3        discussion            10   0.000  0.277  0.277
# 4        discussion            20     NaN    NaN  0.249
# 5           wrapper             0   0.025  0.051  0.026
# 6           wrapper             3     NaN    NaN  0.321
# 7           wrapper             5     NaN    NaN  0.410
# 8           wrapper            10     NaN    NaN  0.438
