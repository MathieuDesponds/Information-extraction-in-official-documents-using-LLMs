# %%
import warnings
warnings.filterwarnings('ignore')

from ner.plot_results import *

# %reload_ext autoreload
# %autoreload 2

# %% [markdown]
# <a id="0"></a> <br>
# # NER with LLM Results
#
# ## Table of Contents
#
# 1. [Ontonote 5 Dataset](#1)
# 1. [Results without finetuning](#2)
#     1. [The impact of few shots](#21)
#     1. [The impact of more explenations](#22)
# 1. [Results with finetuning](#3)
#     1. [The impact of few shots](#31)
#     1. [The impact of more explenations](#32)
# 1. [The impact of finetuning](#4)
#     1. [The impact of few shots](#41)
#     1. [The impact of more explenations](#42)
# 1. [The impact of few shots](#5)

# %% [markdown]
# <a id="1"></a>
# ## Ontonote 5 dataset
# The dataset used is a subset of the Ontonote 5 dataset that contains 18 tags that are `['CARDINAL', 'ORDINAL', 'WORK_OF_ART', 'PERSON', 'LOC', 'DATE', 'PERCENT', 'PRODUCT', 'MONEY', 'FAC', 'TIME', 'ORG', 'QUANTITY', 'LANGUAGE', 'GPE', 'LAW', 'NORP', 'EVENT']`
#
# Sentence with less than 30 tokens were removed

# %% [markdown]
# <a id="2"></a>
# ## Results without finetuning

# %%
df = show_results(with_ft = False)

# %% [markdown]
# <a id="21"></a>
# ### The impact of few shots

# %%
summary, table = show_diff_few_shots(with_ft = False)
print(summary)
# Out:
# For Ontonote5 :
#     The mean difference between results that uses few_shots and those that do not and raw is
#      0.184 with confidence 95% student interval (0.155, 0.212)
# For Conll2003_cleaned :
#     The mean difference between results that uses few_shots and those that do not and raw is
#      0.278 with confidence 95% student interval (0.188, 0.368)

# %% [markdown]
# <a id="22"></a>
# ### The impact of explenations

# %%
summary, table = show_diff_plus_plus(with_ft = False)
print(summary)
# Out:
# For Ontonote5 :
#     The mean difference between results that had a detailled explenation and thos that did not is
#      0.004 with confidence 95% student interval (0.003, 0.005)

# %% [markdown]
# <a id="3"></a>
# ## Results with finetuning

# %%
show_results(with_ft = True)

# %% [markdown]
# <a id="31"></a>
# ### The impact of few shots

# %%
summary, table = show_diff_few_shots(with_ft = True)
print(summary)
# Out:
# For Ontonote5 :
#     The mean difference between results that uses few_shots and those that do not and raw is
#      0.149 with confidence 95% student interval (0.107, 0.190)
# For Conll2003_cleaned :
#     The mean difference between results that uses few_shots and those that do not and raw is
#      nan with confidence 95% student interval (nan, nan)

# %% [markdown]
# <a id="32"></a>
# ### The impact of explenations

# %%
summary, table = show_diff_plus_plus(with_ft = True)
print(summary)
# Out:
# For Ontonote5 :
#     The mean difference between results that had a detailled explenation and thos that did not is
#      -0.002 with confidence 95% student interval (-0.006, 0.002)

# %% [markdown]
# <a id="4"></a>
# ## The impact of finetuning

# %% [markdown]
# <a id="41"></a>
# ### Without any few shots

# %%
summary, table = show_diff_ft(with_few_shots = False)
print(summary)
table
# Out:
# For Ontonote5 :
#     The mean difference between results that used a finetuned model and those that do not is
#      0.017 with confidence 95% student interval (0.008, 0.026)
#
# For Conll2003_cleaned :
#     The mean difference between results that used a finetuned model and those that do not is
#      0.544 with confidence 95% student interval (0.368, 0.719)
# {'ontonote5': with_ft prompt_technique  plus_plus  nb_few_shots  result   True  False
#  0             discussion      False             0   0.012  0.122  0.110
#  1             discussion       True             0   0.003  0.122  0.119
#  2                wrapper      False             0   0.025  0.051  0.026
#  3                wrapper       True             0   0.027  0.048  0.021,
#  'conll2003_cleaned': with_ft prompt_technique  plus_plus  nb_few_shots  result   True  False
#  0             discussion       True             0   0.524  0.668  0.144
#  1                wrapper       True             0   0.563  0.627  0.064}

# %% [markdown]
# <a id="42"></a>
# ### With few shots

# %%
summary, table = show_diff_ft(with_few_shots = True)
print(summary)
table
# Out:
# For Ontonote5 :
#     The mean difference between results that used a finetuned model and those that do not is
#      0.062 with confidence 95% student interval (0.042, 0.082)
#
# For Conll2003_cleaned :
#     The mean difference between results that used a finetuned model and those that do not is
#      nan with confidence 95% student interval (nan, nan)
# {'ontonote5': with_ft prompt_technique  plus_plus  nb_few_shots  result   True  False
#  0             discussion      False             3   0.045  0.281  0.236
#  1             discussion       True             3   0.036  0.274  0.238
#  2                wrapper      False             3   0.086  0.407  0.321
#  3                wrapper       True             3   0.080  0.403  0.323,
#  'conll2003_cleaned': with_ft prompt_technique  plus_plus  nb_few_shots  result   True  False
#  0             discussion       True             3   0.187  0.619  0.432
#  1                wrapper       True             3     NaN    NaN  0.332}

# %% [markdown]
# <a id="5"></a>
# ## Impact of few shots

# %%
show_results_few_shots(datasets = ["ontonote5", "conll2003_cleaned"])
# Out:
#                                model  f1_mean   f1_conf_inter  \
# 58                   mistral-7b-v0.1    0.258  (0.207, 0.309)
# 62                   mistral-7b-v0.1    0.238  (0.202, 0.274)
# 56                   mistral-7b-v0.1    0.236  (0.217, 0.256)
# 65                   mistral-7b-v0.1    0.119  (0.103, 0.135)
# 38                   mistral-7b-v0.1    0.323  (0.297, 0.350)
# 41                   mistral-7b-v0.1    0.021  (0.011, 0.031)
# 24  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.544  (0.499, 0.589)
# 26  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.539  (0.487, 0.592)
# 28  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.274  (0.222, 0.326)
# 30  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.122  (0.106, 0.137)
# 8   mistral-7b-v0.1-ft-raw-2000-Q5_0    0.453  (0.428, 0.477)
# 10  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.410  (0.367, 0.452)
# 11  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.403  (0.368, 0.438)
# 13  mistral-7b-v0.1-ft-raw-2000-Q5_0    0.048  (0.024, 0.072)
#
#    prompt_technique few_shot_tecnique  nb_few_shots precision  plus_plus  \
# 58       discussion          sentence             5       300       True
# 62       discussion          sentence             3       300       True
# 56       discussion          sentence            10       300       True
# 65       discussion          no-shots             0       300       True
# 38          wrapper          sentence             3       300       True
# 41          wrapper          no-shots             0       300       True
# 24       discussion          sentence            10       300       True
# 26       discussion          sentence             5       300       True
# 28       discussion          sentence             3       300       True
# 30       discussion          no-shots             0       300       True
# 8           wrapper          sentence            10       300       True
# 10          wrapper          sentence             5       300       True
# 11          wrapper          sentence             3       300       True
# 13          wrapper          no-shots             0       300       True
#
#        ft                          x_names          tech_name
# 58  False  discussion | Without finetuning  With  5 few shots
# 62  False  discussion | Without finetuning  With  3 few shots
# 56  False  discussion | Without finetuning  With 10 few shots
# 65  False  discussion | Without finetuning  With  0 few shots
# 38  False     wrapper | Without finetuning  With  3 few shots
# 41  False     wrapper | Without finetuning  With  0 few shots
# 24   True     discussion | With finetuning  With 10 few shots
# 26   True     discussion | With finetuning  With  5 few shots
# 28   True     discussion | With finetuning  With  3 few shots
# 30   True     discussion | With finetuning  With  0 few shots
# 8    True        wrapper | With finetuning  With 10 few shots
# 10   True        wrapper | With finetuning  With  5 few shots
# 11   True        wrapper | With finetuning  With  3 few shots
# 13   True        wrapper | With finetuning  With  0 few shots
#                                          model  f1_mean   f1_conf_inter  \
# 67                             mistral-7b-v0.1    0.461  (0.350, 0.572)
# 70                             mistral-7b-v0.1    0.432  (0.356, 0.508)
# 71                             mistral-7b-v0.1    0.144  (0.127, 0.162)
# 43                             mistral-7b-v0.1    0.357  (0.324, 0.390)
# 45                             mistral-7b-v0.1    0.332  (0.297, 0.367)
# 47                             mistral-7b-v0.1    0.064  (0.013, 0.116)
# 87  mistral-7b-v0.1-ft-raw-2000-Q5_0-conll2003    0.668  (0.601, 0.734)
# 86  mistral-7b-v0.1-ft-raw-2000-Q5_0-conll2003    0.619  (0.523, 0.714)
# 85  mistral-7b-v0.1-ft-raw-2000-Q5_0-conll2003    0.627  (0.566, 0.688)
#
#    prompt_technique few_shot_tecnique  nb_few_shots precision  plus_plus  \
# 67       discussion          sentence            10       300       True
# 70       discussion          sentence             3       300       True
# 71       discussion          no-shots             0       300       True
# 43          wrapper          sentence            10       300       True
# 45          wrapper          sentence             3       300       True
# 47          wrapper          no-shots             0       300       True
# 87       discussion          no-shots             0       300       True
# 86       discussion          sentence             3       300       True
# 85          wrapper          no-shots             0       300       True
#
#        ft                          x_names          tech_name
# 67  False  discussion | Without finetuning  With 10 few shots
# 70  False  discussion | Without finetuning  With  3 few shots
# 71  False  discussion | Without finetuning  With  0 few shots
# 43  False     wrapper | Without finetuning  With 10 few shots
# 45  False     wrapper | Without finetuning  With  3 few shots
# 47  False     wrapper | Without finetuning  With  0 few shots
# 87   True     discussion | With finetuning  With  0 few shots
# 86   True     discussion | With finetuning  With  3 few shots
# 85   True        wrapper | With finetuning  With  0 few shots

# %%
summary, table = show_diff_ft_few_shots(datasets = ["ontonote5"])
print(summary)
# Out:
# For Ontonote5 :
#     The mean score increase with few_shots between finetuning and without finetuning is
#      0.06 with confidence 95% student interval (0.025, 0.095)
