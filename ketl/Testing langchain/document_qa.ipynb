# %%
! pip install chromadb
! pip install lark chromadb
! pip install google-cloud-aiplatform
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: chromadb in /home/ketl2/.local/lib/python3.10/site-packages (0.4.16)
# Requirement already satisfied: requests>=2.28 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.10.12)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.103.1)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.23.2)
# Requirement already satisfied: posthog>=2.4.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (3.0.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (4.7.1)
# Requirement already satisfied: pulsar-client>=3.1.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (3.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (1.16.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (1.21.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (1.21.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (1.21.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (0.13.3)
# Requirement already satisfied: pypika>=0.48.9 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (1.59.2)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (28.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: numpy>=1.22.5 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (1.24.4)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb) (2020.6.20)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/ketl2/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /home/ketl2/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.23.4)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/ketl2/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.6.4)
# Requirement already satisfied: requests-oauthlib in /home/ketl2/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/ketl2/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3<2.0,>=1.24.2 in /home/ketl2/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.26.18)
# Requirement already satisfied: coloredlogs in /home/ketl2/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/ketl2/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from onnxruntime>=1.14.1->chromadb) (21.3)
# Requirement already satisfied: protobuf in /home/ketl2/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.0)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.9)
# Requirement already satisfied: deprecated>=1.2.6 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.8.0)
# Requirement already satisfied: backoff<3.0.0,>=1.10.0 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (2.2.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.61.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.21.0 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.21.0)
# Requirement already satisfied: opentelemetry-proto==1.21.0 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.21.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.42b0 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.42b0)
# Requirement already satisfied: monotonic>=1.5 in /usr/lib/python3/dist-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ketl2/.local/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.28->chromadb) (3.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer>=0.9.0->chromadb) (8.0.3)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/ketl2/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /home/ketl2/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/ketl2/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/ketl2/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /home/ketl2/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb) (1.1.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/ketl2/.local/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb) (1.15.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/ketl2/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ketl2/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ketl2/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/ketl2/.local/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/ketl2/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lark in /home/ketl2/.local/lib/python3.10/site-packages (1.1.8)
# Requirement already satisfied: chromadb in /home/ketl2/.local/lib/python3.10/site-packages (0.4.16)
# Requirement already satisfied: requests>=2.28 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic>=1.9 in /usr/local/lib/python3.10/dist-packages (from chromadb) (1.10.12)
# Requirement already satisfied: chroma-hnswlib==0.7.3 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (0.7.3)
# Requirement already satisfied: fastapi>=0.95.2 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.103.1)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.23.2)
# Requirement already satisfied: posthog>=2.4.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (3.0.2)
# Requirement already satisfied: typing-extensions>=4.5.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (4.7.1)
# Requirement already satisfied: pulsar-client>=3.1.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (3.3.0)
# Requirement already satisfied: onnxruntime>=1.14.1 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (1.16.1)
# Requirement already satisfied: opentelemetry-api>=1.2.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (1.21.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-grpc>=1.2.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (1.21.0)
# Requirement already satisfied: opentelemetry-sdk>=1.2.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (1.21.0)
# Requirement already satisfied: tokenizers>=0.13.2 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (0.13.3)
# Requirement already satisfied: pypika>=0.48.9 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (0.48.9)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (4.66.1)
# Requirement already satisfied: overrides>=7.3.1 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (7.4.0)
# Requirement already satisfied: importlib-resources in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (6.1.1)
# Requirement already satisfied: grpcio>=1.58.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (1.59.2)
# Requirement already satisfied: bcrypt>=4.0.1 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (4.0.1)
# Requirement already satisfied: typer>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from chromadb) (0.9.0)
# Requirement already satisfied: kubernetes>=28.1.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (28.1.0)
# Requirement already satisfied: tenacity>=8.2.3 in /usr/local/lib/python3.10/dist-packages (from chromadb) (8.2.3)
# Requirement already satisfied: PyYAML>=6.0.0 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (6.0.1)
# Requirement already satisfied: numpy>=1.22.5 in /home/ketl2/.local/lib/python3.10/site-packages (from chromadb) (1.24.4)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /usr/local/lib/python3.10/dist-packages (from fastapi>=0.95.2->chromadb) (0.27.0)
# Requirement already satisfied: certifi>=14.05.14 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb) (2020.6.20)
# Requirement already satisfied: six>=1.9.0 in /usr/lib/python3/dist-packages (from kubernetes>=28.1.0->chromadb) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /home/ketl2/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.8.2)
# Requirement already satisfied: google-auth>=1.0.1 in /home/ketl2/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (2.23.4)
# Requirement already satisfied: websocket-client!=0.40.0,!=0.41.*,!=0.42.*,>=0.32.0 in /home/ketl2/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.6.4)
# Requirement already satisfied: requests-oauthlib in /home/ketl2/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.3.1)
# Requirement already satisfied: oauthlib>=3.2.2 in /home/ketl2/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (3.2.2)
# Requirement already satisfied: urllib3<2.0,>=1.24.2 in /home/ketl2/.local/lib/python3.10/site-packages (from kubernetes>=28.1.0->chromadb) (1.26.18)
# Requirement already satisfied: coloredlogs in /home/ketl2/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (15.0.1)
# Requirement already satisfied: flatbuffers in /home/ketl2/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: packaging in /usr/lib/python3/dist-packages (from onnxruntime>=1.14.1->chromadb) (21.3)
# Requirement already satisfied: protobuf in /home/ketl2/.local/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (4.25.0)
# Requirement already satisfied: sympy in /usr/lib/python3/dist-packages (from onnxruntime>=1.14.1->chromadb) (1.9)
# Requirement already satisfied: deprecated>=1.2.6 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (1.2.14)
# Requirement already satisfied: importlib-metadata<7.0,>=6.0 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-api>=1.2.0->chromadb) (6.8.0)
# Requirement already satisfied: backoff<3.0.0,>=1.10.0 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (2.2.1)
# Requirement already satisfied: googleapis-common-protos~=1.52 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.61.0)
# Requirement already satisfied: opentelemetry-exporter-otlp-proto-common==1.21.0 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.21.0)
# Requirement already satisfied: opentelemetry-proto==1.21.0 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-exporter-otlp-proto-grpc>=1.2.0->chromadb) (1.21.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.42b0 in /home/ketl2/.local/lib/python3.10/site-packages (from opentelemetry-sdk>=1.2.0->chromadb) (0.42b0)
# Requirement already satisfied: monotonic>=1.5 in /usr/lib/python3/dist-packages (from posthog>=2.4.0->chromadb) (1.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ketl2/.local/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests>=2.28->chromadb) (3.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/lib/python3/dist-packages (from typer>=0.9.0->chromadb) (8.0.3)
# Requirement already satisfied: h11>=0.8 in /usr/local/lib/python3.10/dist-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /home/ketl2/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.1)
# Requirement already satisfied: python-dotenv>=0.13 in /home/ketl2/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /home/ketl2/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: watchfiles>=0.13 in /home/ketl2/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.21.0)
# Requirement already satisfied: websockets>=10.4 in /home/ketl2/.local/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (12.0)
# Requirement already satisfied: sniffio>=1.1 in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<4.0.0,>=3.7.1->fastapi>=0.95.2->chromadb) (1.1.3)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/ketl2/.local/lib/python3.10/site-packages (from deprecated>=1.2.6->opentelemetry-api>=1.2.0->chromadb) (1.15.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/ketl2/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ketl2/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ketl2/.local/lib/python3.10/site-packages (from google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (4.9)
# Requirement already satisfied: zipp>=0.5 in /usr/lib/python3/dist-packages (from importlib-metadata<7.0,>=6.0->opentelemetry-api>=1.2.0->chromadb) (1.0.0)
# Requirement already satisfied: humanfriendly>=9.1 in /home/ketl2/.local/lib/python3.10/site-packages (from coloredlogs->onnxruntime>=1.14.1->chromadb) (10.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/ketl2/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth>=1.0.1->kubernetes>=28.1.0->chromadb) (0.5.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: google-cloud-aiplatform in /home/ketl2/.local/lib/python3.10/site-packages (1.36.1)
# Requirement already satisfied: google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0 in /home/ketl2/.local/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.13.0)
# Requirement already satisfied: proto-plus<2.0.0dev,>=1.22.0 in /home/ketl2/.local/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.22.3)
# Requirement already satisfied: protobuf!=3.20.0,!=3.20.1,!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.19.5 in /home/ketl2/.local/lib/python3.10/site-packages (from google-cloud-aiplatform) (4.25.0)
# Requirement already satisfied: packaging>=14.3 in /usr/lib/python3/dist-packages (from google-cloud-aiplatform) (21.3)
# Requirement already satisfied: google-cloud-storage<3.0.0dev,>=1.32.0 in /home/ketl2/.local/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.13.0)
# Requirement already satisfied: google-cloud-bigquery<4.0.0dev,>=1.15.0 in /home/ketl2/.local/lib/python3.10/site-packages (from google-cloud-aiplatform) (3.13.0)
# Requirement already satisfied: google-cloud-resource-manager<3.0.0dev,>=1.3.3 in /home/ketl2/.local/lib/python3.10/site-packages (from google-cloud-aiplatform) (1.10.4)
# Requirement already satisfied: shapely<3.0.0dev in /home/ketl2/.local/lib/python3.10/site-packages (from google-cloud-aiplatform) (2.0.2)
# Requirement already satisfied: googleapis-common-protos<2.0.dev0,>=1.56.2 in /home/ketl2/.local/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.61.0)
# Requirement already satisfied: google-auth<3.0.dev0,>=2.14.1 in /home/ketl2/.local/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.23.4)
# Requirement already satisfied: requests<3.0.0.dev0,>=2.18.0 in /home/ketl2/.local/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2.31.0)
# Requirement already satisfied: grpcio<2.0dev,>=1.33.2 in /home/ketl2/.local/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.59.2)
# Requirement already satisfied: grpcio-status<2.0.dev0,>=1.33.2 in /home/ketl2/.local/lib/python3.10/site-packages (from google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.59.2)
# Requirement already satisfied: google-cloud-core<3.0.0dev,>=1.6.0 in /home/ketl2/.local/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.3.3)
# Requirement already satisfied: google-resumable-media<3.0dev,>=0.6.0 in /home/ketl2/.local/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.6.0)
# Requirement already satisfied: python-dateutil<3.0dev,>=2.7.2 in /home/ketl2/.local/lib/python3.10/site-packages (from google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (2.8.2)
# Requirement already satisfied: grpc-google-iam-v1<1.0.0dev,>=0.12.4 in /home/ketl2/.local/lib/python3.10/site-packages (from google-cloud-resource-manager<3.0.0dev,>=1.3.3->google-cloud-aiplatform) (0.12.6)
# Requirement already satisfied: google-crc32c<2.0dev,>=1.0 in /home/ketl2/.local/lib/python3.10/site-packages (from google-cloud-storage<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.5.0)
# Requirement already satisfied: numpy>=1.14 in /home/ketl2/.local/lib/python3.10/site-packages (from shapely<3.0.0dev->google-cloud-aiplatform) (1.24.4)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/ketl2/.local/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/ketl2/.local/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/ketl2/.local/lib/python3.10/site-packages (from google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (4.9)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil<3.0dev,>=2.7.2->google-cloud-bigquery<4.0.0dev,>=1.15.0->google-cloud-aiplatform) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/ketl2/.local/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/lib/python3/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/ketl2/.local/lib/python3.10/site-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/lib/python3/dist-packages (from requests<3.0.0.dev0,>=2.18.0->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (2020.6.20)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /home/ketl2/.local/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.dev0,>=2.14.1->google-api-core[grpc]!=2.0.*,!=2.1.*,!=2.2.*,!=2.3.*,!=2.4.*,!=2.5.*,!=2.6.*,!=2.7.*,<3.0.0dev,>=1.32.0->google-cloud-aiplatform) (0.5.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings
from langchain.embeddings.vertexai import VertexAIEmbeddings
from chromadb.utils import embedding_functions
from langchain.schema import Document
from langchain.vectorstores import FAISS


docs = [
    Document(
        page_content="A bunch of scientists bring back dinosaurs and mayhem breaks loose",
        metadata={"year": 1993, "rating": 7.7, "genre": "science fiction"},
    ),
    Document(
        page_content="Leo DiCaprio gets lost in a dream within a dream within a dream within a ...",
        metadata={"year": 2010, "director": "Christopher Nolan", "rating": 8.2},
    ),
    Document(
        page_content="A psychologist / detective gets lost in a series of dreams within dreams within dreams and Inception reused the idea",
        metadata={"year": 2006, "director": "Satoshi Kon", "rating": 8.6},
    ),
    Document(
        page_content="A bunch of normal-sized women are supremely wholesome and some men pine after them",
        metadata={"year": 2019, "director": "Greta Gerwig", "rating": 8.3},
    ),
    Document(
        page_content="Toys come alive and have a blast doing so",
        metadata={"year": 1995, "genre": "animated"},
    ),
    Document(
        page_content="Three men walk into the Zone, three men walk out of the Zone",
        metadata={
            "year": 1979,
            "rating": 9.9,
            "director": "Andrei Tarkovsky",
            "genre": "thriller",
            "rating": 9.9,
        },
    ),
]
# create the open-source embedding function
# embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")
# embedding_function = VertexAIEmbeddings()
# embedding_function = embedding_functions.DefaultEmbeddingFunction()
embedding_function = embedding_functions.SentenceTransformerEmbeddingFunction(model_name="all-MiniLM-L6-v2")

# load it into Chroma
vectorstore = FAISS.from_documents(docs, embedding_function)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_45726/1538803694.py in <module>
#      45
#      46 # load it into Chroma
# ---> 47 vectorstore = FAISS.from_documents(docs, embedding_function)
#      48
#      49
#
# /usr/local/lib/python3.10/dist-packages/langchain/vectorstores/base.py in from_documents(cls, documents, embedding, **kwargs)
#     415         texts = [d.page_content for d in documents]
#     416         metadatas = [d.metadata for d in documents]
# --> 417         return cls.from_texts(texts, embedding, metadatas=metadatas, **kwargs)
#     418
#     419     @classmethod
#
# /usr/local/lib/python3.10/dist-packages/langchain/vectorstores/faiss.py in from_texts(cls, texts, embedding, metadatas, ids, **kwargs)
#     600                 faiss = FAISS.from_texts(texts, embeddings)
#     601         """
# --> 602         embeddings = embedding.embed_documents(texts)
#     603         return cls.__from(
#     604             texts,
#
# AttributeError: 'SentenceTransformerEmbeddingFunction' object has no attribute 'embed_documents'

# %%
from langchain.chat_models import ChatOpenAI
from langchain.chains.query_constructor.base import AttributeInfo
from langchain.retrievers.self_query.base import SelfQueryRetriever


metadata_field_info = [
    AttributeInfo(
        name="genre",
        description="The genre of the movie. One of ['science fiction', 'comedy', 'drama', 'thriller', 'romance', 'action', 'animated']",
        type="string",
    ),
    AttributeInfo(
        name="year",
        description="The year the movie was released",
        type="integer",
    ),
    AttributeInfo(
        name="director",
        description="The name of the movie director",
        type="string",
    ),
    AttributeInfo(
        name="rating", description="A 1-10 rating for the movie", type="float"
    ),
]
document_content_description = "Brief summary of a movie"
llm = ChatOpenAI(temperature=0)
retriever = SelfQueryRetriever.from_llm(
    llm,
    vectorstore,
    document_content_description,
    metadata_field_info,
)

# %% [markdown]
# ## Using DocTran --> only usable with ChatGPT

# %%
import json
from langchain.schema import Document
from langchain.document_transformers import DoctranQATransformer

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_25765/711028232.py in <module>
# ----> 1 from dotenv import load_dotenv
#       2
#       3 load_dotenv()
#
# ModuleNotFoundError: No module named 'dotenv'

# %%
sample_text = """[Generated with ChatGPT]

Confidential Document - For Internal Use Only

Date: July 1, 2023

Subject: Updates and Discussions on Various Topics

Dear Team,

I hope this email finds you well. In this document, I would like to provide you with some important updates and discuss various topics that require our attention. Please treat the information contained herein as highly confidential.

Security and Privacy Measures
As part of our ongoing commitment to ensure the security and privacy of our customers' data, we have implemented robust measures across all our systems. We would like to commend John Doe (email: john.doe@example.com) from the IT department for his diligent work in enhancing our network security. Moving forward, we kindly remind everyone to strictly adhere to our data protection policies and guidelines. Additionally, if you come across any potential security risks or incidents, please report them immediately to our dedicated team at security@example.com.

HR Updates and Employee Benefits
Recently, we welcomed several new team members who have made significant contributions to their respective departments. I would like to recognize Jane Smith (SSN: 049-45-5928) for her outstanding performance in customer service. Jane has consistently received positive feedback from our clients. Furthermore, please remember that the open enrollment period for our employee benefits program is fast approaching. Should you have any questions or require assistance, please contact our HR representative, Michael Johnson (phone: 418-492-3850, email: michael.johnson@example.com).

Marketing Initiatives and Campaigns
Our marketing team has been actively working on developing new strategies to increase brand awareness and drive customer engagement. We would like to thank Sarah Thompson (phone: 415-555-1234) for her exceptional efforts in managing our social media platforms. Sarah has successfully increased our follower base by 20% in the past month alone. Moreover, please mark your calendars for the upcoming product launch event on July 15th. We encourage all team members to attend and support this exciting milestone for our company.

Research and Development Projects
In our pursuit of innovation, our research and development department has been working tirelessly on various projects. I would like to acknowledge the exceptional work of David Rodriguez (email: david.rodriguez@example.com) in his role as project lead. David's contributions to the development of our cutting-edge technology have been instrumental. Furthermore, we would like to remind everyone to share their ideas and suggestions for potential new projects during our monthly R&D brainstorming session, scheduled for July 10th.

Please treat the information in this document with utmost confidentiality and ensure that it is not shared with unauthorized individuals. If you have any questions or concerns regarding the topics discussed, please do not hesitate to reach out to me directly.

Thank you for your attention, and let's continue to work together to achieve our goals.

Best regards,

Jason Fan
Cofounder & CEO
Psychic
jason@psychic.dev
"""

# %%
documents = [Document(page_content=sample_text)]
qa_transformer = DoctranQATransformer()
transformed_document = await qa_transformer.atransform_documents(documents)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_25765/2373049608.py in <module>
#       1 documents = [Document(page_content=sample_text)]
# ----> 2 qa_transformer = DoctranQATransformer()
#       3 transformed_document = await qa_transformer.atransform_documents(documents)
#
# /usr/local/lib/python3.10/dist-packages/langchain/document_transformers/doctran_text_qa.py in __init__(self, openai_api_key, openai_api_model)
#      27         openai_api_model: Optional[str] = None,
#      28     ) -> None:
# ---> 29         self.openai_api_key = openai_api_key or get_from_env(
#      30             "openai_api_key", "OPENAI_API_KEY"
#      31         )
#
# /usr/local/lib/python3.10/dist-packages/langchain/utils/env.py in get_from_env(key, env_key, default)
#      20         return default
#      21     else:
# ---> 22         raise ValueError(
#      23             f"Did not find {key}, please add an environment variable"
#      24             f" `{env_key}` which contains it, or pass"
#
# ValueError: Did not find openai_api_key, please add an environment variable `OPENAI_API_KEY` which contains it, or pass  `openai_api_key` as a named parameter.
