# %%
from llm.LLMModel import *
from ner.llm_ner.prompt_techniques.pt_abstract import PromptTechnique
from ner.llm_ner.prompt_techniques.pt_discussion import PT_OutputList
from ner.llm_ner.prompt_techniques.pt_gpt_ner import PT_GPT_NER
from ner.llm_ner.prompt_techniques.pt_wrapper import PT_Wrapper
from ner.llm_ner.prompt_techniques.pt_filing import PT_Filing
from ner.llm_ner.few_shots_techniques import *
# %reload_ext autoreload
# %autoreload 2

for pt in [PT_Wrapper, PT_GPT_NER]:
    LLMModel.finetune(pt(None), runs = 2000, precision = "raw", cleaned = False)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Some weights of the model checkpoint at dslim/bert-base-NER were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Map:   0%|          | 0/2000 [00:00<?, ? examples/s]
# The model will be trained on 1951 train samples and on 50 evaluation samples
# Failed to detect the name of this notebook, you can set it manually with the WANDB_NOTEBOOK_NAME environment variable to enable code saving.
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:wandb: Paste an API key from yo ...
# Traceback (most recent call last):
#   File "/root/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py", line 1166, in init
#     wi.setup(kwargs)
#   File "/root/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py", line 306, in setup
#     wandb_login._login(
#   File "/root/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_login.py", line 298, in _login
#     wlogin.prompt_api_key()
#   File "/root/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_login.py", line 221, in prompt_api_key
#     key, status = self._prompt_api_key()
#                   ^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_login.py", line 201, in _prompt_api_key
#     key = apikey.prompt_api_key(
#           ^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/apikey.py", line 144, in prompt_api_key
#     key = input_callback(api_ask).strip()
#           ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/lib/python3.11/site-packages/click/termui.py", line 164, in prompt
#     value = prompt_func(prompt)
#             ^^^^^^^^^^^^^^^^^^^
#   File "/root/miniconda3/lib/python3.11/site-packages/click/termui.py", line 147, in prompt_func
#     raise Abort() from None
# click.exceptions.Abort
# ---------------------------------------------------------------------------
# Abort                                     Traceback (most recent call last)
# File ~/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:1166, in init(job_type, dir, config, project, entity, reinit, tags, group, name, notes, magic, config_exclude_keys, config_include_keys, anonymous, mode, allow_val_change, resume, force, tensorboard, sync_tensorboard, monitor_gym, save_code, id, settings)
#    1165 wi = _WandbInit()
# -> 1166 wi.setup(kwargs)
#    1167 assert wi.settings
#
# File ~/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:306, in _WandbInit.setup(self, kwargs)
#     305 if not settings._offline and not settings._noop:
# --> 306     wandb_login._login(
#     307         anonymous=kwargs.pop("anonymous", None),
#     308         force=kwargs.pop("force", None),
#     309         _disable_warning=True,
#     310         _silent=settings.quiet or settings.silent,
#     311         _entity=kwargs.get("entity") or settings.entity,
#     312     )
#     314 # apply updated global state after login was handled
#
# File ~/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_login.py:298, in _login(anonymous, key, relogin, host, force, timeout, _backend, _silent, _disable_warning, _entity)
#     297 if not key:
# --> 298     wlogin.prompt_api_key()
#     300 # make sure login credentials get to the backend
#
# File ~/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_login.py:221, in _WandbLogin.prompt_api_key(self)
#     220 def prompt_api_key(self):
# --> 221     key, status = self._prompt_api_key()
#     222     if status == ApiKeyStatus.NOTTY:
#
# File ~/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_login.py:201, in _WandbLogin._prompt_api_key(self)
#     200 try:
# --> 201     key = apikey.prompt_api_key(
#     202         self._settings,
#     203         api=api,
#     204         no_offline=self._settings.force if self._settings else None,
#     205         no_create=self._settings.force if self._settings else None,
#     206     )
#     207 except ValueError as e:
#     208     # invalid key provided, try again
#
# File ~/miniconda3/lib/python3.11/site-packages/wandb/sdk/lib/apikey.py:144, in prompt_api_key(settings, api, input_callback, browser_callback, no_offline, no_create, local)
#     141     wandb.termlog(
#     142         f"You can find your API key in your browser here: {app_url}/authorize"
#     143     )
# --> 144     key = input_callback(api_ask).strip()
#     145 write_key(settings, key, api=api)
#
# File ~/miniconda3/lib/python3.11/site-packages/click/termui.py:164, in prompt(text, default, hide_input, confirmation_prompt, type, value_proc, prompt_suffix, show_default, err, show_choices)
#     163 while True:
# --> 164     value = prompt_func(prompt)
#     165     if value:
#
# File ~/miniconda3/lib/python3.11/site-packages/click/termui.py:147, in prompt.<locals>.prompt_func(text)
#     146     echo(None, err=err)
# --> 147 raise Abort() from None
#
# Abort:
#
# The above exception was the direct cause of the following exception:
#
# Error                                     Traceback (most recent call last)
# /myhome/Master-thesis/finetune copy.ipynb Cell 1 line 1
#       <a href='vscode-notebook-cell://ssh-remote%2B127.0.0.1/myhome/Master-thesis/finetune%20copy.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a> get_ipython().run_line_magic('autoreload', '2')
#      <a href='vscode-notebook-cell://ssh-remote%2B127.0.0.1/myhome/Master-thesis/finetune%20copy.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=10'>11</a> for pt in [PT_Wrapper, PT_GPT_NER]:
# ---> <a href='vscode-notebook-cell://ssh-remote%2B127.0.0.1/myhome/Master-thesis/finetune%20copy.ipynb#W0sdnNjb2RlLXJlbW90ZQ%3D%3D?line=11'>12</a>     LLMModel.finetune(pt(None), runs = 2000, precision = "raw", cleaned = False)
#
# File /myhome/Master-thesis/llm/LLMModel.py:265, in LLMModel.finetune(pt, base_model_id, runs, cleaned, precision, checkpoint)
#     263 if checkpoint :
#     264     trainer.train(resume_from_checkpoint = True)
# --> 265 trainer.train()
#     266 trainer.save_model()
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/trainer.py:1555, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1553         hf_hub_utils.enable_progress_bars()
#    1554 else:
# -> 1555     return inner_training_loop(
#    1556         args=args,
#    1557         resume_from_checkpoint=resume_from_checkpoint,
#    1558         trial=trial,
#    1559         ignore_keys_for_eval=ignore_keys_for_eval,
#    1560     )
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/trainer.py:1789, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1786 self._globalstep_last_logged = self.state.global_step
#    1787 model.zero_grad()
# -> 1789 self.control = self.callback_handler.on_train_begin(args, self.state, self.control)
#    1791 # Skip the first epochs_trained epochs to get the random state of the dataloader at the right point.
#    1792 if not args.ignore_data_skip:
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/trainer_callback.py:363, in CallbackHandler.on_train_begin(self, args, state, control)
#     361 def on_train_begin(self, args: TrainingArguments, state: TrainerState, control: TrainerControl):
#     362     control.should_training_stop = False
# --> 363     return self.call_event("on_train_begin", args, state, control)
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/trainer_callback.py:407, in CallbackHandler.call_event(self, event, args, state, control, **kwargs)
#     405 def call_event(self, event, args, state, control, **kwargs):
#     406     for callback in self.callbacks:
# --> 407         result = getattr(callback, event)(
#     408             args,
#     409             state,
#     410             control,
#     411             model=self.model,
#     412             tokenizer=self.tokenizer,
#     413             optimizer=self.optimizer,
#     414             lr_scheduler=self.lr_scheduler,
#     415             train_dataloader=self.train_dataloader,
#     416             eval_dataloader=self.eval_dataloader,
#     417             **kwargs,
#     418         )
#     419         # A Callback can skip the return of `control` if it doesn't change it.
#     420         if result is not None:
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/integrations/integration_utils.py:763, in WandbCallback.on_train_begin(self, args, state, control, model, **kwargs)
#     761     args.run_name = None
#     762 if not self._initialized:
# --> 763     self.setup(args, state, model, **kwargs)
#
# File ~/miniconda3/lib/python3.11/site-packages/transformers/integrations/integration_utils.py:736, in WandbCallback.setup(self, args, state, model, **kwargs)
#     733         init_args["name"] = args.run_name
#     735 if self._wandb.run is None:
# --> 736     self._wandb.init(
#     737         project=os.getenv("WANDB_PROJECT", "huggingface"),
#     738         **init_args,
#     739     )
#     740 # add config parameters (run may have been created manually)
#     741 self._wandb.config.update(combined_dict, allow_val_change=True)
#
# File ~/miniconda3/lib/python3.11/site-packages/wandb/sdk/wandb_init.py:1208, in init(job_type, dir, config, project, entity, reinit, tags, group, name, notes, magic, config_exclude_keys, config_include_keys, anonymous, mode, allow_val_change, resume, force, tensorboard, sync_tensorboard, monitor_gym, save_code, id, settings)
#    1206             wandb.termerror("Abnormal program exit")
#    1207             os._exit(1)
# -> 1208         raise Error("An unexpected error occurred") from error_seen
#    1209 return run
#
# Error: An unexpected error occurred

# %%
from llm.LLMModel import *
from ner.llm_ner.prompt_techniques.pt_abstract import PromptTechnique
from ner.llm_ner.prompt_techniques.pt_discussion import PT_OutputList
from ner.llm_ner.prompt_techniques.pt_gpt_ner import PT_GPT_NER
from ner.llm_ner.prompt_techniques.pt_wrapper import PT_Wrapper
from ner.llm_ner.prompt_techniques.pt_filing import PT_Filing
from ner.llm_ner.few_shots_techniques import *
# %reload_ext autoreload
# %autoreload 2

for pt in [PT_Filing] : #[PT_OutputList, PT_Wrapper, PT_2Time_Tagger,PT_Filing] : 
    model.finetune(pt(None), runs = 2000, precision = "noshots", cleaned = False)
    model.finetune(pt(None), runs = 2000, precision = "++_noshots", cleaned = False)

# %%
from ner.Datasets.OntoNotes5Dataset import OntoNote5Dataset
train, test = OntoNote5Dataset.my_load_dataset()

# %%
from ner.llm_ner.prompt_techniques.pt_discussion import PT_OutputList
from ner.llm_ner.few_shots_techniques import *
# %reload_ext autoreload
# %autoreload 2
from ner.Datasets.OntoNotes5Dataset import OntoNote5Dataset
train, test = OntoNote5Dataset.my_load_dataset()
pt = PT_OutputList(None)

pt.process_dataset_for_finetuning(dataset = train, precision = "", runs = 4000)
pt.process_dataset_for_finetuning(dataset = train, precision = "noshots", fst = FST_NoShots, runs = 4000, nb_few_shots=[0])

# %%
from ner.llm_ner.prompt_techniques.pt_wrapper import PT_Wrapper
from ner.llm_ner.few_shots_techniques import *
# %reload_ext autoreload
# %autoreload 2
from ner.Datasets.OntoNotes5Dataset import OntoNote5Dataset
train, test = OntoNote5Dataset.my_load_dataset()
pt = PT_Wrapper(None)

pt.process_dataset_for_finetuning(dataset = train, precision = "", runs = 4000)
pt.process_dataset_for_finetuning(dataset = train, precision = "noshots", fst = FST_NoShots, runs = 4000, nb_few_shots=[0])

# %%
from ner.utils import load

dataset = load("./ner/saves/datasets/conll2003_for-ft_cleaned_discussion_noshots_10000.pkl")

# %%
dataset.select(range(5000))

# %%
from ner.utils import dump
dump(dataset, "./ner/saves/datasets/conll2003_for-ft_cleaned_discussion_noshots_5000.pkl")
